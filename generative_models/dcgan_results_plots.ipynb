# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from all parameters
# nz data
nz = [64, 100, 120]
fid42_nz = [140.3138, 151.3831, 151.4166]
fid43_nz = [158.8395, 159.0467, 162.7306]
fid44_nz = [138.7121, 134.4721, 140.4673]
fid45_nz = [153.3757, 148.3162, 145.1294]
fid46_nz = [146.443, 130.2857, 132.8221]
mean_fid_nz = [147.5368, 144.7008, 146.5132]

# ngf data
ngf = [32, 64, 128]
fid42_ngf = [171.6613, 151.3831, 154.4586]
fid43_ngf = [149.0506, 159.0467, 158.2708]
fid44_ngf = [133.7915, 134.4721, 144.4893]
fid45_ngf = [153.288, 148.3162, 152.9684]
fid46_ngf = [149.1511, 130.2857, 145.5303]
mean_fid_ngf = [151.3885, 144.7008, 151.1435]

# ndf data
ndf = [32, 64, 128]
fid42_ndf = [166.8029, 151.3831, 353.22]
fid43_ndf = [158.6512, 159.0467, 146.1768]
fid44_ndf = [160.1426, 134.4721, 317.9066]
fid45_ndf = [162.0534, 148.3162, 282.1052]
fid46_ndf = [161.6764, 130.2857, 337.4706]
mean_fid_ndf = [161.8653, 144.7008, 287.3758]

# lr data
lr = [0.0001, 0.0002, 0.0003]
fid42_lr = [174.291, 151.3831, 152.2237]
fid43_lr = [156.3872, 159.0467, 144.2265]
fid44_lr = [205.2109, 134.4721, 144.6404]
fid45_lr = [149.0871, 148.3162, 127.7178]
fid46_lr = [146.762, 130.2857, 132.7849]
mean_fid_lr = [166.3476, 144.7008, 140.3186]

# beta1 data
beta1 = [0.4, 0.5, 0.6]
fid42_beta1 = [141.6535, 151.3831, 147.8295]
fid43_beta1 = [143.2962, 159.0467, 159.3352]
fid44_beta1 = [133.975, 134.4721, 141.55]
fid45_beta1 = [132.4778, 148.3162, 140.5929]
fid46_beta1 = [135.5683, 130.2857, 150.0761]
mean_fid_beta1 = [137.3941, 144.7008, 147.8767]

# epochs data
epochs = [120, 150, 200, 250, 400]
fid42_epochs = [151.3831, 141.2737, 152.3366, 135.6079, 153.1775]
fid43_epochs = [159.0467, 143.2639, 138.6849, 148.4432, 142.2877]
fid44_epochs = [134.4721, 137.3003, 134.0533, 152.3642, 140.6169]
fid45_epochs = [148.3162, 150.0142, 139.7724, 153.7472, 143.3793]
fid46_epochs = [130.2857, 147.5126, 154.4035, 160.4984, 136.7634]
mean_fid_epochs = [144.7008, 143.8729, 143.8502, 150.1322, 143.245]

# Create figure with subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('FID vs Hyperparameters', fontsize=16)

# Plot function
def plot_fid(ax, x, fid42, fid43, fid44, fid45, fid46, mean_fid, title, xlabel):
    ax.plot(x, fid42, '--', label='FID_42', alpha=0.7)
    ax.plot(x, fid43, '--', label='FID_43', alpha=0.7)
    ax.plot(x, fid44, '--', label='FID_44', alpha=0.7)
    ax.plot(x, fid45, '--', label='FID_45', alpha=0.7)
    ax.plot(x, fid46, '--', label='FID_46', alpha=0.7)
    ax.plot(x, mean_fid, '-', linewidth=2, label='Mean FID')
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel('FID Score')
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.6)

# Plot each parameter
plot_fid(axes[0, 0], nz, fid42_nz, fid43_nz, fid44_nz, fid45_nz, fid46_nz, mean_fid_nz, 'FID vs nz', 'nz')
plot_fid(axes[0, 1], ngf, fid42_ngf, fid43_ngf, fid44_ngf, fid45_ngf, fid46_ngf, mean_fid_ngf, 'FID vs ngf', 'ngf')
plot_fid(axes[0, 2], ndf, fid42_ndf, fid43_ndf, fid44_ndf, fid45_ndf, fid46_ndf, mean_fid_ndf, 'FID vs ndf', 'ndf')
plot_fid(axes[1, 0], lr, fid42_lr, fid43_lr, fid44_lr, fid45_lr, fid46_lr, mean_fid_lr, 'FID vs Learning Rate', 'Learning Rate')
plot_fid(axes[1, 1], beta1, fid42_beta1, fid43_beta1, fid44_beta1, fid45_beta1, fid46_beta1, mean_fid_beta1, 'FID vs Beta1', 'Beta1')
plot_fid(axes[1, 2], epochs, fid42_epochs, fid43_epochs, fid44_epochs, fid45_epochs, fid46_epochs, mean_fid_epochs, 'FID vs Epochs', 'Epochs')

# Adjust layout and show plot
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Cats and Dogs

# nz data
nz = [64, 100, 120]
fid42_nz = [322.6944, 327.5605, 324.0157]
fid43_nz = [318.2429, 321.0252, 320.9411]
fid44_nz = [334.5952, 321.6675, 321.2669]
mean_fid_nz = [325.1775, 323.4178, 322.0746]

# ngf data
ngf = [32, 64, 128]
fid42_ngf = [319.6867, 322.6944, 325.27]
fid43_ngf = [325.1199, 318.2429, 318.4566]
fid44_ngf = [332.1277, 334.5952, 320.2109]
mean_fid_ngf = [325.6448, 325.1775, 321.3125]

# ndf data
ndf = [32, 64, 128]
fid42_ndf = [325.7629, 322.6944, 474.2227]
fid43_ndf = [321.0057, 318.2429, 337.6748]
fid44_ndf = [307.9859, 334.5952, 469.1585]
mean_fid_ndf = [318.2515, 325.1775, 427.0187]

# lr data
lr = [0.0001, 0.0002, 0.0003]
fid42_lr = [321.3643, 322.6944, 335.6162]
fid43_lr = [321.0317, 318.2429, 326.3561]
fid44_lr = [323.5781, 334.5952, 327.8047]
mean_fid_lr = [321.9914, 325.1775, 329.9257]

# beta1 data
beta1 = [0.4, 0.5, 0.6]
fid42_beta1 = [326.6002, 322.6944, 336.4035]
fid43_beta1 = [322.4004, 318.2429, 327.4142]
fid44_beta1 = [330.3593, 334.5952, 321.8512]
mean_fid_beta1 = [326.4533, 325.1775, 328.5563]

# epochs data
epochs = [120, 150, 200, 250, 400]
fid42_epochs = [322.6944, 320.3062, 330.7121, 318.3959, 313.5749]
fid43_epochs = [318.2429, 317.2861, 318.991, 313.6579, 314.5834]
fid44_epochs = [334.5952, 314.4978, 326.0783, 318.1827, 314.8883]
mean_fid_epochs = [325.1775, 317.3634, 325.2605, 316.7455, 314.3489]

# Create figure with subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('FID vs Hyperparameters', fontsize=16)

# Plot function
def plot_fid(ax, x, fid42, fid43, fid44, mean_fid, title, xlabel):
    ax.plot(x, fid42, '--', label='FID_42', alpha=0.7)
    ax.plot(x, fid43, '--', label='FID_43', alpha=0.7)
    ax.plot(x, fid44, '--', label='FID_44', alpha=0.7)
    ax.plot(x, mean_fid, '-', linewidth=2, label='Mean FID')
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel('FID Score')
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.6)

# Plot each parameter
plot_fid(axes[0, 0], nz, fid42_nz, fid43_nz, fid44_nz, mean_fid_nz, 'FID vs nz', 'nz')
plot_fid(axes[0, 1], ngf, fid42_ngf, fid43_ngf, fid44_ngf, mean_fid_ngf, 'FID vs ngf', 'ngf')
plot_fid(axes[0, 2], ndf, fid42_ndf, fid43_ndf, fid44_ndf, mean_fid_ndf, 'FID vs ndf', 'ndf')
plot_fid(axes[1, 0], lr, fid42_lr, fid43_lr, fid44_lr, mean_fid_lr, 'FID vs Learning Rate', 'Learning Rate')
plot_fid(axes[1, 1], beta1, fid42_beta1, fid43_beta1, fid44_beta1, mean_fid_beta1, 'FID vs Beta1', 'Beta1')
plot_fid(axes[1, 2], epochs, fid42_epochs, fid43_epochs, fid44_epochs, mean_fid_epochs, 'FID vs Epochs', 'Epochs')

# Adjust layout and show plot
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()
