# %%
batch = [16, 32, 64, 128]
acc_batch = [0.952006981, 0.959181695, 0.960926895, 0.962866007]
acc1_batch = [0.954915649, 0.95927865, 0.956806283, 0.964659686]
acc2_batch = [0.946625945, 0.962187318, 0.962623618, 0.963350785]
acc3_batch = [0.954479348, 0.956079116, 0.963350785, 0.960587551]

lr = [0.1, 0.01, 0.001, 0.0001]
acc_lr = [0.891118868, 0.906340896, 0.959181695, 0.970913322]
acc1_lr = [0.869691681, 0.897033159, 0.95927865, 0.969022688]
acc2_lr = [0.90866783, 0.904159395, 0.962187318, 0.974549156]
acc3_lr = [0.894997091, 0.917830134, 0.956079116, 0.969168121]

wd = [0.1, 0.01, 0.001, 0.0001]
acc_wd = [0.620709715, 0.895287958, 0.96039364, 0.957678883]

epochs = [10, 20, 50, 100]
acc_epochs = [0.94982548, 0.957678883, 0.958163661, 0.957824316]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a larger figure
fig, axs = plt.subplots(2, 2, figsize=(12, 8))  # Adjust width and height as needed
fig.suptitle('Accuracy')

# Plot your data
axs[0, 0].plot(batch, acc_batch)
axs[0, 0].plot(batch, acc1_batch, '--')
axs[0, 0].plot(batch, acc2_batch, '--')
axs[0, 0].plot(batch, acc3_batch, '--')
axs[0, 0].set_title('Batch Size')
axs[0, 1].plot(lr, acc_lr)
axs[0, 1].plot(lr, acc1_lr, '--')
axs[0, 1].plot(lr, acc2_lr, '--')
axs[0, 1].plot(lr, acc3_lr, '--')
#axs[0, 1].set_xscale('log')
axs[0, 1].set_title('Learning Rate')
axs[1, 0].plot(wd, acc_wd)
axs[1, 0].set_title('Weight Decay')
axs[1, 1].plot(epochs, acc_epochs)
axs[1, 1].set_title('Epochs Number')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
