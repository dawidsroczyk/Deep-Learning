# %%
# VGG-like
batch = [16, 32, 64, 128]
acc_batch = [0.957048672, 0.957678883, 0.959860384, 0.958503006]
acc1_batch = [0.958260617, 0.956806283, 0.960296684, 0.95840605]
acc2_batch = [0.953606748, 0.95840605, 0.961314718, 0.95884235]
acc3_batch = [0.95927865, 0.957824316, 0.95796975, 0.958260617]

lr = [0.1, 0.01, 0.001, 0.0001]
acc_lr = [0.871146015, 0.802743843, 0.957678883, 0.962623618]
acc1_lr = [0.887579988, 0.620709715, 0.956806283, 0.963059919]
acc2_lr = [0.858347877, 0.910703898, 0.95840605, 0.961314718]
acc3_lr = [0.86751018, 0.876817917, 0.957824316, 0.963496219]

wd = [0.1, 0.01, 0.001, 0.0001]
acc_wd = [0.620709715, 0.895287958, 0.96039364, 0.957678883]
acc1_wd = [0.620709715, 0.893397324, 0.959133217, 0.956806283]
acc2_wd = [0.620709715, 0.886416521, 0.960005817, 0.95840605]
acc3_wd = [0.620709715, 0.906050029, 0.962041885, 0.957824316]

epochs = [10, 20, 50, 100]
acc_epochs = [0.94982548, 0.957678883, 0.958163661, 0.957824316]
acc1_epochs = [0.948371146, 0.956806283, 0.95796975, 0.957242583]
acc2_epochs = [0.94895288, 0.95840605, 0.958696917, 0.958696917]
acc3_epochs = [0.952152414, 0.957824316, 0.957824316, 0.95753345]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Accuracy')

axs[0, 0].plot(batch, acc_batch)
axs[0, 0].plot(batch, acc1_batch, '--')
axs[0, 0].plot(batch, acc2_batch, '--')
axs[0, 0].plot(batch, acc3_batch, '--')
axs[0, 0].set_title('Batch Size')

axs[0, 1].plot(lr, acc_lr)
axs[0, 1].plot(lr, acc1_lr, '--')
axs[0, 1].plot(lr, acc2_lr, '--')
axs[0, 1].plot(lr, acc3_lr, '--')
axs[0, 1].set_xscale('log')
axs[0, 1].set_title('Learning Rate')

axs[1, 0].plot(wd, acc_wd)
axs[1, 0].plot(wd, acc1_wd, '--')
axs[1, 0].plot(wd, acc2_wd, '--')
axs[1, 0].plot(wd, acc3_wd, '--')
axs[1, 0].set_xscale('log')
axs[1, 0].set_title('Weight Decay')

axs[1, 1].plot(epochs, acc_epochs)
axs[1, 1].plot(epochs, acc1_epochs, '--')
axs[1, 1].plot(epochs, acc2_epochs, '--')
axs[1, 1].plot(epochs, acc3_epochs, '--')
axs[1, 1].set_title('Epochs Number')

plt.tight_layout()
plt.show()

# %%
# ResNet-like
batch = [16, 32, 64, 128]
acc_batch = [0.952006981, 0.959181695, 0.960926895, 0.962866007]
acc1_batch = [0.954915649, 0.95927865, 0.956806283, 0.964659686]
acc2_batch = [0.946625945, 0.962187318, 0.962623618, 0.963350785]
acc3_batch = [0.954479348, 0.956079116, 0.963350785, 0.960587551]

lr = [0.1, 0.01, 0.001, 0.0001]
acc_lr = [0.891118868, 0.906340896, 0.959181695, 0.970913322]
acc1_lr = [0.869691681, 0.897033159, 0.95927865, 0.969022688]
acc2_lr = [0.90866783, 0.904159395, 0.962187318, 0.974549156]
acc3_lr = [0.894997091, 0.917830134, 0.956079116, 0.969168121]

wd = [0.1, 0.01, 0.001, 0.0001]
acc_wd = [0.620709715, 0.729687803, 0.93154935, 0.959181695]
acc1_wd = [0.620709715, 0.838423502, 0.932955207, 0.95927865]
acc2_wd = [0.620709715, 0.624490983, 0.926410704, 0.962187318]
acc3_wd = [0.620709715, 0.726148924, 0.935282141, 0.956079116]

epochs = [10, 20, 50, 100]
acc_epochs = [0.951279814, 0.959181695, 0.960345162, 0.960151251]
acc1_epochs = [0.950552647, 0.95927865, 0.961314718, 0.961314718]
acc2_epochs = [0.954333915, 0.962187318, 0.963496219, 0.962914485]
acc3_epochs = [0.94895288, 0.956079116, 0.956224549, 0.956224549]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Accuracy')

axs[0, 0].plot(batch, acc_batch)
axs[0, 0].plot(batch, acc1_batch, '--')
axs[0, 0].plot(batch, acc2_batch, '--')
axs[0, 0].plot(batch, acc3_batch, '--')
axs[0, 0].set_title('Batch Size')

axs[0, 1].plot(lr, acc_lr)
axs[0, 1].plot(lr, acc1_lr, '--')
axs[0, 1].plot(lr, acc2_lr, '--')
axs[0, 1].plot(lr, acc3_lr, '--')
axs[0, 1].set_xscale('log')
axs[0, 1].set_title('Learning Rate')

axs[1, 0].plot(wd, acc_wd)
axs[1, 0].plot(wd, acc1_wd, '--')
axs[1, 0].plot(wd, acc2_wd, '--')
axs[1, 0].plot(wd, acc3_wd, '--')
axs[1, 0].set_xscale('log')
axs[1, 0].set_title('Weight Decay')

axs[1, 1].plot(epochs, acc_epochs)
axs[1, 1].plot(epochs, acc1_epochs, '--')
axs[1, 1].plot(epochs, acc2_epochs, '--')
axs[1, 1].plot(epochs, acc3_epochs, '--')
axs[1, 1].set_title('Epochs Number')

plt.tight_layout()
plt.show()

# %%
# VGG-like vsu
batch = [16, 32, 64, 128]
acc_batch = [0.951037425, 0.961557107, 0.964223386, 0.963496219]
acc1_batch = [0.946771379, 0.960151251, 0.960151251, 0.961751018]
acc2_batch = [0.955061082, 0.964950553, 0.965968586, 0.962041885]
acc3_batch = [0.951279814, 0.959569517, 0.96655032, 0.966695753]

lr = [0.1, 0.01, 0.001, 0.0001]
acc_lr = [0.793823929, 0.922726391, 0.961557107, 0.966938142]
acc1_lr = [0.620709715, 0.915648633, 0.960151251, 0.96698662]
acc2_lr = [0.880162885, 0.935427574, 0.964950553, 0.965386853]
acc3_lr = [0.880599186, 0.917102967, 0.959569517, 0.968440954]

wd = [0.1, 0.01, 0.001, 0.0001]
acc_wd = [0.620709715, 0.893639713, 0.940517743, 0.961557107]
acc1_wd = [0.620709715, 0.905177429, 0.929755672, 0.960151251]
acc2_wd = [0.620709715, 0.913030832, 0.942408377, 0.964950553]
acc3_wd = [0.620709715, 0.862710878, 0.94938918, 0.959569517]

epochs = [10, 20, 50, 100]
acc_epochs = [0.955303471, 0.961557107, 0.961847974, 0.961944929]
acc1_epochs = [0.952734148, 0.960151251, 0.961896451, 0.962041885]
acc2_epochs = [0.961460151, 0.964950553, 0.964805119, 0.964950553]
acc3_epochs = [0.951716114, 0.959569517, 0.95884235, 0.95884235]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Accuracy')

axs[0, 0].plot(batch, acc_batch)
axs[0, 0].plot(batch, acc1_batch, '--')
axs[0, 0].plot(batch, acc2_batch, '--')
axs[0, 0].plot(batch, acc3_batch, '--')
axs[0, 0].set_title('Batch Size')

axs[0, 1].plot(lr, acc_lr)
axs[0, 1].plot(lr, acc1_lr, '--')
axs[0, 1].plot(lr, acc2_lr, '--')
axs[0, 1].plot(lr, acc3_lr, '--')
axs[0, 1].set_xscale('log')
axs[0, 1].set_title('Learning Rate')

axs[1, 0].plot(wd, acc_wd)
axs[1, 0].plot(wd, acc1_wd, '--')
axs[1, 0].plot(wd, acc2_wd, '--')
axs[1, 0].plot(wd, acc3_wd, '--')
axs[1, 0].set_xscale('log')
axs[1, 0].set_title('Weight Decay')

axs[1, 1].plot(epochs, acc_epochs)
axs[1, 1].plot(epochs, acc1_epochs, '--')
axs[1, 1].plot(epochs, acc2_epochs, '--')
axs[1, 1].plot(epochs, acc3_epochs, '--')
axs[1, 1].set_title('Epochs Number')

plt.tight_layout()
plt.show()
