# %%
# !git clone --branch dawid/transformers https://github.com/dawidsroczyk/Deep-Learning.git
# !mv Deep-Learning/transformers/* .
# !gdown 1zXnV-209gkJSC2kfdOHfAttBLNtzKd4L
# !gdown 1kk9KX2crJvb5YzuF2OBMkLLE0vbOG8tc
# !gdown 1GMYLTBi2J0z8tFkDe0sHvw284C4D9Ru5
# !mkdir models
# !mkdir output
# Out:
# Cloning into 'Deep-Learning'...
# remote: Enumerating objects: 2313, done.
# remote: Counting objects: 100% (854/854), done.
# remote: Compressing objects: 100% (470/470), done.
# remote: Total 2313 (delta 443), reused 789 (delta 383), pack-reused 1459 (from 3)
# Receiving objects: 100% (2313/2313), 97.86 MiB | 17.44 MiB/s, done.
# Resolving deltas: 100% (1082/1082), done.
# Downloading...
# From (original): https://drive.google.com/uc?id=1zXnV-209gkJSC2kfdOHfAttBLNtzKd4L
# From (redirected): https://drive.google.com/uc?id=1zXnV-209gkJSC2kfdOHfAttBLNtzKd4L&confirm=t&uuid=06181236-0192-4a96-8ac3-49056a042013
# To: /content/test.pt
# 100% 321M/321M [00:05<00:00, 53.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1kk9KX2crJvb5YzuF2OBMkLLE0vbOG8tc
# From (redirected): https://drive.google.com/uc?id=1kk9KX2crJvb5YzuF2OBMkLLE0vbOG8tc&confirm=t&uuid=d4743184-2b5a-4d05-a36e-0539c04b8917
# To: /content/train.pt
# 100% 1.28G/1.28G [00:21<00:00, 59.5MB/s]
# ...

# %%
from ast_11_sigmoid_batch_padding import train_ast

# %%
# !rm -rf models
# !rm -rf output
# !mkdir models
# !mkdir output

# %%
# !mkdir models_bs1
# !mkdir output_bs1
train_ast(
    num_epochs=30,
    num_classes=11,
    lr=1e-5,
    weight_decay=0.05,
    model_path='models_bs1',
    train_data_path='train.pt',
    test_data_path='test.pt',
    unknown_data_path='unknown.pt',
    confusion_matrices_path='output_bs1',
    random_seed=987,
    unknown_threshold=0.8,
    batch_size=1
)
# Out:
# {'silence': 0, 'yes': 1, 'off': 2, 'down': 3, 'on': 4, 'up': 5, 'right': 6, 'stop': 7, 'go': 8, 'left': 9, 'no': 10}
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /content/ast_11_sigmoid_batch_padding.py:206: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Streaming output truncated to the last 5000 lines.
# --------------------------------------------------
# 0 / 20862
# 100 / 20862
# 200 / 20862
# 300 / 20862
# 400 / 20862
# 500 / 20862
# 600 / 20862
# 700 / 20862
# 800 / 20862
# 900 / 20862
# 1000 / 20862
# 1100 / 20862
# 1200 / 20862
# 1300 / 20862
# 1400 / 20862
# 1500 / 20862
# 1600 / 20862
# 1700 / 20862
# 1800 / 20862
# ...

# %%
# !zip -r output_bs1.zip output_bs1/*

# %%
# !mkdir models_bs2
# !mkdir output_bs2
train_ast(
    num_epochs=30,
    num_classes=11,
    lr=1e-5,
    weight_decay=0.05,
    model_path='models_bs2',
    train_data_path='train.pt',
    test_data_path='test.pt',
    unknown_data_path='unknown.pt',
    confusion_matrices_path='output_bs2',
    random_seed=987,
    unknown_threshold=0.8,
    batch_size=2
)
# Out:
# mkdir: cannot create directory ‘models_bs2’: File exists
# mkdir: cannot create directory ‘output_bs2’: File exists
# {'silence': 0, 'yes': 1, 'off': 2, 'down': 3, 'on': 4, 'up': 5, 'right': 6, 'stop': 7, 'go': 8, 'left': 9, 'no': 10}
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /content/ast_11_sigmoid_batch_padding.py:206: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# 0 / 10431
# 100 / 10431
# 200 / 10431
# 300 / 10431
# 400 / 10431
# 500 / 10431
# 600 / 10431
# 700 / 10431
# 800 / 10431
# 900 / 10431
# 1000 / 10431
# 1100 / 10431
# 1200 / 10431
# 1300 / 10431
# 1400 / 10431
# 1500 / 10431
# 1600 / 10431
# 1700 / 10431
# ...

# %%
train_ast(
    num_epochs=30,
    num_classes=11,
    lr=1e-5,
    weight_decay=0.05,
    model_path='models',
    train_data_path='train.pt',
    test_data_path='test.pt',
    unknown_data_path='unknown.pt',
    confusion_matrices_path='output',
    random_seed=987,
    unknown_threshold=0.8,
    batch_size=4
)
# Out:
# {'silence': 0, 'yes': 1, 'off': 2, 'down': 3, 'on': 4, 'up': 5, 'right': 6, 'stop': 7, 'go': 8, 'left': 9, 'no': 10}
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /content/ast_11_sigmoid_batch_padding.py:206: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# 0 / 5216
# 100 / 5216
# 200 / 5216
# 300 / 5216
# 400 / 5216
# 500 / 5216
# 600 / 5216
# 700 / 5216
# 800 / 5216
# 900 / 5216
# 1000 / 5216
# 1100 / 5216
# 1200 / 5216
# 1300 / 5216
# 1400 / 5216
# 1500 / 5216
# 1600 / 5216
# 1700 / 5216
# 1800 / 5216
# 1900 / 5216
# 2000 / 5216
# 2100 / 5216
# 2200 / 5216
# 2300 / 5216
# 2400 / 5216
# 2500 / 5216
# 2600 / 5216
# 2700 / 5216
# ...

# %%
train_ast(
    num_epochs=30,
    num_classes=11,
    lr=1e-5,
    weight_decay=0.05,
    model_path='models',
    train_data_path='train.pt',
    test_data_path='test.pt',
    unknown_data_path='unknown.pt',
    confusion_matrices_path='output',
    random_seed=987,
    unknown_threshold=0.8,
    batch_size=8
)
# Out:
# {'silence': 0, 'yes': 1, 'off': 2, 'down': 3, 'on': 4, 'up': 5, 'right': 6, 'stop': 7, 'go': 8, 'left': 9, 'no': 10}
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /content/ast_11_sigmoid_batch_padding.py:206: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# 0 / 2608
# 100 / 2608
# 200 / 2608
# 300 / 2608
# 400 / 2608
# 500 / 2608
# 600 / 2608
# 700 / 2608
# 800 / 2608
# 900 / 2608
# 1000 / 2608
# 1100 / 2608
# 1200 / 2608
# 1300 / 2608
# 1400 / 2608
# 1500 / 2608
# 1600 / 2608
# 1700 / 2608
# 1800 / 2608
# 1900 / 2608
# 2000 / 2608
# 2100 / 2608
# 2200 / 2608
# 2300 / 2608
# 2400 / 2608
# 2500 / 2608
# 2600 / 2608
# Epoch 1/30
# ...

# %%
# !zip -r output_bs16.zip output/*
# Out:
#   adding: output/epoch_10_confusion_matrices.json (deflated 89%)
#   adding: output/epoch_11_confusion_matrices.json (deflated 89%)
#   adding: output/epoch_12_confusion_matrices.json (deflated 89%)
#   adding: output/epoch_13_confusion_matrices.json (deflated 89%)
#   adding: output/epoch_14_confusion_matrices.json (deflated 89%)
#   adding: output/epoch_15_confusion_matrices.json (deflated 90%)
#   adding: output/epoch_16_confusion_matrices.json (deflated 90%)
#   adding: output/epoch_17_confusion_matrices.json (deflated 90%)
#   adding: output/epoch_18_confusion_matrices.json (deflated 90%)
#   adding: output/epoch_19_confusion_matrices.json (deflated 90%)
#   adding: output/epoch_1_confusion_matrices.json (deflated 89%)
#   adding: output/epoch_20_confusion_matrices.json (deflated 90%)
#   adding: output/epoch_2_confusion_matrices.json (deflated 89%)
#   adding: output/epoch_3_confusion_matrices.json (deflated 89%)
# ...
